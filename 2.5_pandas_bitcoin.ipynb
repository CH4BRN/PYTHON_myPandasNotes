# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
print("Setup complete")
# Out:
# Setup complete

# %%
d = pd.read_csv('cours-du-bitcoin.csv')
d.head()
# Out:
#    2018-02-18 00:00:00  8680.27000000
# 0  2018-02-17 00:00:00        8246.05
# 1  2018-02-16 00:00:00        8139.95
# 2  2018-02-15 00:00:00        7570.40
# 3  2018-02-14 00:00:00        7286.13
# 4  2018-02-13 00:00:00        7108.61

# %%
d.describe().round(2)
# Out:
#        8680.27000000
# count        1847.00
# mean         1170.68
# std          2377.20
# min            13.05
# 25%           219.32
# 50%           382.72
# 75%           701.33
# max         16376.30

# %%
d.loc[d['8680.27000000']==16376.30]
# Out:
#     2018-02-18 00:00:00  8680.27000000
# 61  2017-12-18 00:00:00        16376.3

# %%
d.loc[d['8680.27000000']>10000]
# Out:
#     2018-02-18 00:00:00  8680.27000000
# 26  2018-01-22 00:00:00       10538.09
# 31  2018-01-17 00:00:00       11192.51
# 32  2018-01-16 00:00:00       11300.22
# 33  2018-01-15 00:00:00       11797.41
# 34  2018-01-14 00:00:00       11497.98
# 35  2018-01-13 00:00:00       11144.19
# 36  2018-01-12 00:00:00       12427.96
# 37  2018-01-11 00:00:00       12125.31
# 38  2018-01-10 00:00:00       12618.13
# 39  2018-01-09 00:00:00       13490.26
# 40  2018-01-08 00:00:00       14338.58
# 41  2018-01-07 00:00:00       14183.30
# 42  2018-01-06 00:00:00       12725.41
# 43  2018-01-05 00:00:00       12786.04
# 44  2018-01-04 00:00:00       12319.79
# 45  2018-01-03 00:00:00       11391.39
# 46  2018-01-02 00:00:00       11850.31
# 47  2018-01-01 00:00:00       10654.40
# 48  2017-12-31 00:00:00       12247.68
# 49  2017-12-30 00:00:00       12264.02
# 50  2017-12-29 00:00:00       13087.45
# 51  2017-12-28 00:00:00       13259.28
# 52  2017-12-27 00:00:00       11733.82
# ...

# %%
d.plot()
plt.show()

# %%
date = pd.date_range('2013-01-28','2018-02-17')

# %%
index1 = pd.DatetimeIndex(date)

# %%
del d['2018-02-18 00:00:00']
d['2018-02-18 00:00:00'] = index1

# %%
d = d.set_index('2018-02-18 00:00:00')

# %%
d.plot()
plt.show()
